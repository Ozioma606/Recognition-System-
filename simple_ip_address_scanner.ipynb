# %% [markdown]
# <a href="https://colab.research.google.com/github/Ozioma606/Recognition-System-/blob/main/simple_ip_address_scanner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scapy
# basic_network_scanner.py
from scapy.all import ARP, Ether, srp
import ipaddress

def scan_network(network_range):
    print(f"Scanning network: {network_range}")

    # Create ARP request packet
    arp = ARP(pdst=network_range)
    ether = Ether(dst="ff:ff:ff:ff:ff:ff")  # Broadcast MAC
    packet = ether/arp

    result = srp(packet, timeout=2, verbose=0)[0]

    # Parse result
    clients = []
    for sent, received in result:
        clients.append({'ip': received.psrc, 'mac': received.hwsrc})

    # Print results
    print("Available devices in the network:")
    print("IP" + " "*18 + "MAC")
    for client in clients:
        print(f"{client['ip']:20} {client['mac']}")

# Replace with your subnet (e.g. 192.168.1.0/24)
scan_network("192.168.1.0/24")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 18.3 MB/s eta 0:00:00
# ...
# Scanning network: 192.168.1.0/24
# Available devices in the network:
# IP                  MAC
